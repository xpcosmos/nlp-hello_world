# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
# Reading data
df = pd.read_csv('../data/raw_data/tweet-sentiment-extraction/train.csv')

# %% [markdown]
# # Análise de frequência de palavras.

# %%
print(f'Shape: {df.shape}')
df.head()
# Out:
# Shape: (27481, 4)
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
# Analyzing the frequency of sentiments
ax = df['sentiment'].value_counts().sort_index().plot(kind='bar', 
                                                 title='Frequency of sentiment',
                                                 figsize=(10,5))
plt.show()

# %% [markdown]
# # Visualizing the SentimentIntensityAnalyzer
#
# Creating a first analysis using a relatively simple algorithm

# %%
df_sia = pd.read_csv('../data/processed_data/twitter/df_sia.csv')

# %%
fig, axs = plt.subplots(1, 4, figsize=(15, 3))

sns.boxplot(df_sia, x='sentiment', y='compound', ax=axs[0])
sns.boxplot(df_sia, x='sentiment', y ='pos', ax=axs[1])
sns.boxplot(df_sia, x='sentiment', y ='neu', ax=axs[2])
sns.boxplot(df_sia, x='sentiment', y ='neg', ax=axs[3])

axs[0].set_title('Compound')
axs[1].set_title('pos')
axs[2].set_title('Neu')
axs[3].set_title('Neg')

plt.show()

# %% [markdown]
# # Visualização de nuvens de palavras.

# %% [markdown]
# # Análise de tópicos
